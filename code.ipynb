# %%
from matplotlib import pyplot as plt
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager

from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# %%
from importlib.metadata import PackageNotFoundError, version
from matplotlib import pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager

from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator

def pkg_versions():
    pkgs = ["qiskit", "qiskit-ibm-runtime", "matplotlib", "numpy"]
    out = {}
    for p in pkgs:
        try:
            out[p] = version(p)
        except PackageNotFoundError:
            out[p] = "NOT INSTALLED"
    return out

{"package_versions": pkg_versions()}
# Out:
# {'package_versions': {'qiskit': '2.3.0',
#   'qiskit-ibm-runtime': '0.45.1',
#   'matplotlib': '3.10.8',
#   'numpy': '2.4.2'}}

# %%
API_KEY = "FXNA0d9hcDEgB-UcCi1tjPi-QWD4bT55eoXuwJFVE_JC"  # 

service = QiskitRuntimeService(
    channel="ibm_quantum_platform",
    token=API_KEY,
)

"Auth OK"
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-02-26 21:56:16,233: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-02-26 21:56:54,794: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# 'Auth OK'

# %%
backend = service.least_busy(simulator=True, operational=True)
{"selected_backend": backend.name}
# Out:
# qiskit_runtime_service.backends:WARNING:2026-02-26 21:59:33,484: Loading instance: open-instance, plan: open
# ---------------------------------------------------------------------------
# QiskitBackendNotFoundError                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 backend = service.least_busy(simulator=True, operational=True)
#       2 {"selected_backend": backend.name}
#
# File ~\Desktop\Research\my_repo\virtual_env\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:1319, in QiskitRuntimeService.least_busy(self, min_num_qubits, instance, filters, **kwargs)
#    1317     candidates = list(filter(lambda b: b["qubits"] >= min_num_qubits, candidates))
#    1318 if not candidates:
# -> 1319     raise QiskitBackendNotFoundError("No backend matches the criteria.")
#    1320 sorted_backends = sorted(candidates, key=lambda b: b["queue_length"])
#    1321 for back in sorted_backends:
#    1322     # We don't know whether or not the backend has a valid config
#
# QiskitBackendNotFoundError: 'No backend matches the criteria.'
